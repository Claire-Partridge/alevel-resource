# %% [markdown]
# ### <font color = purple> $\mathtt{If\ this\ presentation\ doesn't\ begin\ automatically,\ it's\ likely\ because\ you\ don't\ have\\ the\ RISE\ package\ installed\ on\ your\ computer. }$
# ### <font color = purple> $\mathtt{Run\ the}$ `pip install` $\mathtt{code\ in\ the\ cell\ below\ to\ do\ this. }$
# > ### <font color = purple> $ \mathtt{To\ run\ a\ cell\ press\ the\ Shift\ [\Uparrow]\  +\ Enter\ [\hookleftarrow]\ keys\ }$ </font>
# ### <font color = purple> $\mathtt{Then\ shutdown\ the\ notebook\ and\ restart.\ You\ should\ find\ the\ following\ button\\ appears\ in\ the\ control\ bar\ above\ next\ to\ the\ keyboard\ button:}$ </font>
#
# ![Enter/Exit RISE Slideshow](attachment:Screenshot%202021-03-10%20at%2015.17.48.png)
#
# > ### <font color = purple> $\mathtt{It\ is\ not\ necessary\ to\ run\ this\ worksheet\ as\ a\ presentation\\ the\ work\ can\ still\ be\ done\ out\ of\ presentation\ mode.\\ In\ this\ case\ however,\ you\ will\ still\ need\ to\ pip\ install\ the\ magic-markdown\ package\ and\ shutdown\ and\ restart\ the\ notebook}$

# %%
pip install RISE

# %% [markdown]
# <a id="shutdown_notebook"></a>
# ### <font color = purple> **$\mathtt{To\ fully\ shutdown\ the\ notebook,\ close\ this\ window,\\ go\ to\ the\ location\ of\ the\ file\ in\ the\ notebook\\ interface\ which\ looks\ like\ this: }$** </font>
#
# ![Jupyter Notebook Interface](attachment:Screenshot%202021-03-23%20at%2014.38.26.png)

# %% [markdown]
# <font color = purple> $\mathtt{Click\ the\ box\ next\ to\ the\ open\ notebook:}$ </font>
# ![Screenshot%202021-03-23%20at%2014.44.10.png](attachment:Screenshot%202021-03-23%20at%2014.44.10.png)
# <font color = purple> $\mathtt{From\ the\ options\ that\ appear\ at\ the\ top\ choose\ Shutdown\ and\ then\ re-open\ the\ notebook }$</font>

# %% [markdown]
# <font color = purple> $\mathtt{ To\ ensure\ all\ your\ answers\ are\ formatted\ correctly\\ you\ must\ import\ the\ following\ package.\ To\ do\ this\\ simply\ run\ the\ following\ cell: }$
# > <font color = purple> $ \mathtt{To\ run\ a\ cell\ press\ the\ Shift\ [\Uparrow]\  +\ Enter\ [\hookleftarrow]\ keys\ }$ </font>

# %%
pip install magic-markdown

# %% [markdown]
# <font color = purple> $\mathtt{When\ a\ cell\ has\ been\ run,\ the\ item\ in\ the\ square\\ brackets\ []\
#     will\ change\ from\ an\ asterisk\ to\ a\ number. }$

# %% [markdown]
# <font color = purple> $\mathtt{Once\ you\ have\ installed\ this\ package\ you\ need\ to\ fully\\ shutdown\ and\ re-open\ this\ worksheet\ as\ before,\\ To\ view\ the\ instructions\ on\ how\ to\ do\ this\\ exit\ the\ presentation\ and\ see:\\ }$
#
# [$\mathtt{Notebook\ Shutdown\ Instructions}$](#shutdown_notebook)

# %% [markdown]
# ### <font color = purple> $\mathtt{Boyle's\ law\ and\ Charles'\ Law\\ A2\ Required\ Practical\  }$
# > #### <font color = purple> $\mathtt{Introduction\ and\\ Experimental\ Procedure }$

# %% [markdown]
# #### <font color = purple> $\mathtt{If\ you\ are\ new\ to\ Python\ and\ would\\ like\ to\ explore\ before\ getting\\ started,\ click\ for\ a }$
# #### <a href = "https://docs.python.org/3/tutorial/index.html" target="_blank"> <font color = blue> $\mathtt{ Beginners'\ Tutorial.\\ }$ </a>
# > <font color = purple> $\mathtt{This\ isn't\ required\ for\ this\ worksheet,\\ remember - \ Google\ is\ your\ bestfriend!!\\ }$

# %% [markdown]
# <font color = purple> $\mathtt{If\ you\ run\ a\ cell\ and\ you\ receive\ an\ error\\ Ensure\ you\ have\ done\ the\ following:\ }$
#   - $\mathtt{All\ file\ titles\ are\ simple,\ have\ no\ spaces\\ or\ special\ characters\ and\ are\ spelt\ consistently.}$
#   - $\mathtt{Each\ column\ heading\ within\ the\ files\ follow\\ the\ same\ rules\ as\ above.}$
#   - $\mathtt{Every\ new\ variable\ must\ have\ a\ different\ name.}$
#   - $\mathtt{Every\ variable\ name\ must\ be\ spelt\ consistently\\ the\ same.\ (Don't\ worry\ about\ grammar\ or\ spelling,\\ Python\ doesn't\ judge\ as\ long\ as\ they\ are\ the\ same) }$

# %% [markdown]
# <font color =purple> $\mathtt{As\ a\ tip\ - it\ would\ be\ easier\ to\ change\ the\ name\\ of\ your\ file\ and\ column\ headings\ rather\ than\\ change\ the\ name\ in\ the\ code;\ as\ the\ name\ likely\\ re-occurs\ throughout,\ so\ you\ would\ have\ to\ change\\ the\ name\ everytime\ it\ appears\ rather\ than\ just\ once! }$

# %% [markdown]
# <font color = purple> $\mathtt{Cells\ highlighted\ in\ blue\ are\ ready\ to\ be\ run\ once\\ you\ have\ edited\ it: }$
# - $\mathtt{editing\ and\ running\ of\ cells\ can\ be\\ done\ in\ presentation\ mode. }$

# %% [markdown]
#  <font color = purple> $\mathtt{First,\ some\ Boilerplate\ code\ must\ be\ run\\ to\ import\ all\ relevant\ packages: }$

# %%
from IPython.display import display, Math, Latex, HTML, Image
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn
from scipy.optimize import least_squares

# %config InlineBackend.figure_format = 'retina'
# %matplotlib inline
# %load_ext magic_markdown

# %% [markdown]
# ## <font color= purple> $\mathtt{Boyle's\ Law }$
# > <font color = purple> $\mathtt{p_1V_1 = constant}$
#
# > <font color = purple> $\mathtt{When\ kept\ at\ a\ constant\ temperature,\\ the\ pressure\ and\ volume\ of\\ an\ ideal\ gas\ are\ inversely\\ proportional!\\ }$

# %% [markdown]
# <font color = purple> $\mathtt{Your\ task\ is\ to\ produce\ a\\ plot\ of\ pressure\ against\ the\\ inverse\ of\ volume.\ From\ this\\ description\ of\ Boyle's\ Law,\ what\\ do\ you\ expect\ your\ plot\\ to \ look\ like?\ }$

# %%
boyles_init_desc = 'Describe\ and\ explain\ the\ results\ you\ expect\ here.\ '

# ensure you have a backslash and a space between each word in
# the '' marks! -> this is for read-ability at the end!

# %store boyles_init_desc

# %% [markdown]
# ![Screenshot%202021-05-02%20at%2019.02.04.png](attachment:Screenshot%202021-05-02%20at%2019.02.04.png)

# %% [markdown]
# <font color = purple> $\mathtt{Method: }$
# ![BMethod.png](attachment:BMethod.png)

# %% [markdown]
# <font color = purple> $\mathtt{After\ reading\ the\ methodology\ of\ this\ experiment,\\ What\ do\ you\ think\ are\ your\ Independent\ variables?\ }$

# %%
boyles_in_vars = 'List\ your\ independent\ variables\ here.\ '

# %store boyles_in_vars

# %% [markdown]
# <font color = purple> $\mathtt{Explain\ why\ you\ chose\ these\ as\ independent\ variables\ }$

# %%
boyles_in_vars_reasons = 'Explain\ your\ list\ of\ independent\ variables\ here.\ '

# %store boyles_in_vars_reasons

# %% [markdown]
# <font color = purple> $\mathtt{Now\ list\ your\ dependent\ variables\ and\ explain\\ your\ choices}$

# %%
boyles_dep_vars = 'List\ your\ dependent\ variables\ here.\ '

# %store boyles_dep_vars


boyles_dep_vars_reasons = 'Explain\ your\ dependent\ variables\ here.\ '

# %store boyles_dep_vars_reasons

# %% [markdown]
# <font color = purple> $\mathtt{Are\ there\ any\ control\ variables?\ List\ them\ below\ and\\ explain\ your\ choices.\ }$

# %%
boyles_con_vars = 'List\ your\ control\ variables\ here.\ '

# %store boyles_con_vars


boyles_con_vars_reasons = 'Explain\ your\ control\ variables\ here.\ '

# %store boyles_con_vars_reasons

# %% [markdown]
# ### <font color = purple> $\mathtt{Boyle's\ Law\ and\ Charles'\ Law\\ A-level\ required\ practical }$ </font>
#
# > #### <font color = purple> **$\mathtt{Data\ Analysis\ Section}$** </font>

# %% [markdown]
# <font color = purple> $\mathtt{Now,\ inflate\ the\ sandwich\ bag\ and\ input\ its\\ dimensions\
# (in\ cm)\ in\ the\ cell\ below\ and\ run\ it: }$ </font>

# %%
length = 15 #cm
width = 10 #cm


inflated_height = 9 #cm


inflated_Vol_atmp = length*width*inflated_height #cm^3

# %% [markdown]
# ### <font color = purple> $\mathtt{Now,\ you\ need\ to\ import\ your\\ pressure\ Data\ from\ PhyPhox.\ }$
# > <font color = purple> $\mathtt{In\ the\ cell\ below,\ the\ .csv\ file\ has\ been\ named }$  `atm_pressure_data`

# %% [markdown]
# <font color = purple> $\mathtt{\\ Ensure\ the\ code\ in\ red\ quotation\ marks\\  matches\ the\ name\ of\ the\ .csv\ file\ you\ wish\ to\ import!}$ </font>

# %% [markdown]
# <font color = purple> $\mathtt{Top\ Tip:\\ It\ will\ be\ easier\ (and\ much\ less\\ likely\ for\ errors\ to\ occur)\ if\ you\\ change\ the\ name\ of\ your\ file\ to\\ match\ the\ name\ in\ red\ quotation\ marks! }$

# %%
dataframe_atm = pd.read_csv("atm_pressure_data.csv", header=0)

# %% [markdown]
# <font color = purple> $\mathtt{Now\ attribute\ the\ data\ in\ each\ column\ to\ your\\ x-data\ or\ y-data}$
# > $\mathtt{The\ data\ must\ be\ made\ into\ an\ array\ in\ order\ to\ be\\ in\ the\ correct\ format\ to\ plot.}$ </font>
# > <font color = purple> $\mathtt{ This\ is\ what\ the}$ `np.array()`$\mathtt{\ input\ is\ for.}$ </font>

# %%
xData = np.array(dataframe_atm.time)
yData = np.array(dataframe_atm.pressure)

# %% [markdown]
# ## <font color = purple> $\mathtt{Now\ we\ can\ plot\ the\ data:}$

# %%
fig = plt.figure(figsize = (8, 6))
plt.plot(xData,yData, label = 'phyphox data', color = 'pink', marker = 'o', mfc = 'm')
plt.xlabel('\n time / s ')
plt.ylabel('pressure / hPa\n')
plt.grid(color = 'purple', alpha = 0.25, linestyle = '--')
plt.legend()
plt.title('Pressure.csv import\n')
plt.tight_layout()
plt.show();
# Out:
# <img src="data:image/png;base64,..." width="800">

# %% [markdown]
# ### <font color = purple> $\mathtt{Now\ to\ calculate\ the\ average\ pressure: }$

# %%
average_pressure = (2*np.sum(yData))/dataframe_atm.size


print("Average atm pressure = {:5.2f} kPa ".format(average_pressure/10))
# Out:
# Average atm pressure = 101.11 kPa

# %% [markdown]
# ### <font color= purple> $\mathtt{Input\ height\ measurements\ and\\ Calculate\ volume: }$

# %%
obj1_total_height = 10 #cm
obj2_total_height = 10 #cm
obj3_total_height = 10 #cm


obj1_height = 5 #cm
obj2_height = 4 #cm
obj3_height = 3 #cm


inflated_height_obj1 = obj1_total_height - obj1_height #cm
inflated_height_obj2 = obj2_total_height - obj2_height #cm
inflated_height_obj3 = obj3_total_height - obj3_height #cm


inflated_Vol_obj1 = length*width*inflated_height_obj1 #cm^3
inflated_Vol_obj2 = length*width*inflated_height_obj2 #cm^3
inflated_Vol_obj3 = length*width*inflated_height_obj3 #cm^3


print("Volume Object 1 = {:5.2f} cm^3 ".format(inflated_Vol_obj1))
print("Volume Object 2 = {:5.2f} cm^3 ".format(inflated_Vol_obj2))
print("Volume Object 3 = {:5.2f} cm^3 ".format(inflated_Vol_obj3))
# Out:
# Volume Object 1 = 750.00 cm^3
# Volume Object 2 = 900.00 cm^3
# Volume Object 3 = 1050.00 cm^3

# %% [markdown]
# <font color = purple> $\mathtt{All\ measurements\ must\ have\ an\ uncertainty,\\ What\ is\ the\ uncertainty\ of\ a\ ruler?}$

# %%
error_on_ruler = 0.1 #cm

# %% [markdown]
# <font color = purple> $\mathtt{If\ each\ measurement\ with\ the\ ruler\ has\ an\ error,\\ What\ will\ the\ error\ on\ the\ volume\ calculation\ be?}$
# > $\mathtt{Change\ the\ equation\ in\ the\ code\ to\ match\ your\ theory }$

# %%
vol_err = error_on_ruler*3 #cm


print("Volume no object = {:5.2f} +- {:5.2f} cm^3 ".format(inflated_Vol_atmp, vol_err))
print("Volume Object 1 = {:5.2f} +- {:5.2f} cm^3 ".format(inflated_Vol_obj1, vol_err))
print("Volume Object 2 = {:5.2f} +- {:5.2f} cm^3 ".format(inflated_Vol_obj2, vol_err))
print("Volume Object 3 = {:5.2f} +- {:5.2f} cm^3 ".format(inflated_Vol_obj3, vol_err))
# Out:
# Volume no object = 1350.00 +-  0.30 cm^3
# Volume Object 1 = 750.00 +-  0.30 cm^3
# Volume Object 2 = 900.00 +-  0.30 cm^3
# Volume Object 3 = 1050.00 +-  0.30 cm^3

# %% [markdown]
# <font color = purple> $\mathtt{When\ performing\ this\ part\ of\ the\ experiment\\ did\ you\ find\ any\ issues\ with\ your\ equipment?\\ If\ so\ what\ did\ you\ do\ to\ correct\ this? }$

# %%
boyles_equip_issues = 'List\ your\ equipment\ issues\ here\ '

# %store boyles_equip_issues

boyles_equip_decisions = 'Explain\ how\ you\ overcame\ these\ issues\ here\ '

# %store boyles_equip_decisions

# %% [markdown]
# <font color = purple> $\mathtt{Now\ collect\ pressure\ data\ for\ each\ object\ you\ use,\\ this\ can\ be\ any\ number\ of\ objects\\ to\ add\ more\ than\ the\ three\ the\ code\ defines\\ just\ copy,\ paste,\ and,\ rename\ the\ data\ accordingly}$

# %%
dataframe_obj1 = pd.read_csv("atm_pressure_data.csv", header=0)
x_obj1Data = np.array(dataframe_obj1.time)
y_obj1Data = np.array(dataframe_obj1.pressure)

average_pressure_obj1 = ((2*np.sum(y_obj1Data))/dataframe_atm.size)


print("Average atm pressure = {:5.2f} kPa ".format(average_pressure_obj1/10))
# Out:
# Average atm pressure = 5055.30 kPa

# %%
dataframe_obj2 = pd.read_csv("atm_pressure_data.csv", header=0)

x_obj2Data = np.array(dataframe_obj2.time)
y_obj2Data = np.array(dataframe_obj2.pressure)

average_pressure_obj2 = ((2*np.sum(y_obj2Data))/dataframe_atm.size)


print("Average atm pressure = {:5.2f} kPa ".format(average_pressure_obj2/10))
# Out:
# Average atm pressure = 2527.65 kPa

# %%
dataframe_obj3 = pd.read_csv("atm_pressure_data.csv", header=0)

x_obj3Data = np.array(dataframe_obj3.time)
y_obj3Data = np.array(dataframe_obj3.pressure)

average_pressure_obj3 = ((2*np.sum(y_obj3Data))/dataframe_atm.size)


print("Average atm pressure = {:5.2f} kPa ".format(average_pressure_obj3/10))
# Out:
# Average atm pressure = 1516.59 kPa

# %% [markdown]
# <font color = purple> $\mathtt{Up\ to\ this\ point\ have\ you\ encountered\\ any\ issues\ with\ the\ method?\ If\ so,\\ please\ describe\ and\ explain\ the\ issues\\ you\ encountered\ and\ what\ method\ you\\ used\ to\ overcome\ them }$

# %%
boyles_method_issues = 'List\ your\ issues\ here.\ '

# %store boyles_method_issues

boyles_method_decisions = 'Explain\ how\ you\ overcame\ these\ issues\ here\ '

# %store boyles_method_decisions

# %% [markdown]
# <font color= purple> $\mathtt{Coded\ below\ are\ your\ data\ and\\ their\ respective\ errors.\ These\\ are\ then\ assigned\ names\ to\ be\\ used\ in\ your\ plot! }$

# %%
ydata_boyles = [1/inflated_Vol_atmp, 1/inflated_Vol_obj1, 1/inflated_Vol_obj2, 1/inflated_Vol_obj3]
yerror_boyles = 1/10000*vol_err
xdata_boyles = [average_pressure, average_pressure_obj1, average_pressure_obj2, average_pressure_obj3]
xerror_boyles = 1/(np.sqrt(xdata_boyles[0:4]))

# %% [markdown]
# <font color = purple> $\mathtt{Every\ experiment\ encounters\\ errors.\ There\ are\ two\ main\\ types:\ }$
#
# > $\mathtt{Systematic\ errors,\ and\\ Random\ errors. }$
#
# $\mathtt{In\ the\ cell\ below,\ identify\ and\\ explain\ the\ origins\ of\\ the\ two\ types\\ of\ errors\ in\ your\ experiment. }$

# %%
boyles_syst_err = 'Identify\ and\ explain\ your\ systematic\ errors\ here.\ '

# %store boyles_syst_err

boyles_rand_err = 'Identify\ and\ explain\ your\ random\ errors\ here.\ '

# %store boyles_rand_err

# %% [markdown]
# <font color = purple> $\mathtt{Continue\ running\ each\ code\ cell\ along\ the\ way! }$

# %%
xData = xdata_boyles
yData = ydata_boyles
xError = xerror_boyles
yError = yerror_boyles

# %%
m = 0.51     # gradient guess
c = 1        # intercept guess

initParams = np.array([m,c])
pInit = initParams

nPoints = len(xData)
nPars = len(initParams)

# %%
def fitFunc(p, x):
    '''
    Fit function
    '''
    f = p[0] + p[1]*x
    return f

def fitFuncDiff(p, x):
    '''
    Differential of fit function
    '''
    df = p[1]
    return df

def calcChiSq(p, x, y, xerr, yerr):
    '''
    Error function for fit
    '''
    e = (y - fitFunc(p, x))/(np.sqrt(yerr**2 + fitFuncDiff(p, x)**2*xerr**2))
    return e

def fitError(p, x, y, xerr, yerr):
    '''
    Error function for straight line fit
    '''
    e = (y - fitFunc(p, x))/(np.sqrt(yerr**2 + fitFuncDiff(p, x)**2*xerr**2))
    return e

# %%
def fitStdError(jacMatrix):

    # Compute covariance
    jMat2 = np.dot(jacMatrix.T, jacMatrix)
    detJmat2 = np.linalg.det(jMat2)
    
    # Prepare output
    output = np.zeros(jMat2.shape[0])
    if detJmat2 < 1E-32:
        print("Value of determinat detJmat2",detJmat2)
        print("Matrix singular, error calculation failed.")
        return output
    else:
        covar = np.linalg.inv(jMat2)
        for i in range(len(output)):
            output[i] = np.sqrt(covar[i, i])
            
        return output

# %%
xData = np.array(xdata_boyles)
yData = np.array(ydata_boyles)
xError = np.array(xerror_boyles)
yError = np.array(yerror_boyles)

pInit = initParams

# Run fit
output = least_squares(calcChiSq, pInit, args = (xData, yData, xError, yError))

# Get least_squares output, stored in array output.x[]
A = output.x[0]
b = output.x[1]

# Get errors from our fits using fitStdError(), defined above
pErrors = fitStdError(output.jac)
d_A = pErrors[0]
d_b = pErrors[1]

# Calculate chis**2 per point, summed chi**2 and chi**2/NDF
chiarr = calcChiSq(output.x, xData, yData, xError, yError)**2
chisq = np.sum(chiarr)
NDF = nPoints - nPars
chisqndf = chisq/NDF

# Calculate fitted y-values using our fit parameters and the original fit function
xPlot = np.linspace(np.min(xData), np.max(xData), 300)
fitData = fitFunc(output.x, xPlot)

# %% [markdown]
# <font color = purple> $\mathtt{Parameters\ fitted\ by\ the\ algorithm: }$

# %%
print("Fitted parameters m: {0:.10f}, c: {1:.2f}".format(A, b))
print("Parameter errors: m: {0:.10f}, c: {1:.2f}".format(d_A, d_b))
print("ChiSq = {:5.5e}, ChiSq/NDF = {:5.10f}.".format(chisq, chisqndf))
# Make the plot of the data and the fit
# Out:
# Fitted parameters m: 0.0007618841, c: 0.00
# Parameter errors: m: 0.0000242631, c: 0.00
# ChiSq = 4.93949e+00, ChiSq/NDF = 2.4697445499.

# %% [markdown]
# > <font color = purple> $\mathtt{The\ `ChiSq/NDF`\ value\ above\\ gives\ a\ quantitative\ value\ for\\ how\ good\ the\ fit\ represents\\ the\ data.\ As\ a\ general\ guide,\\ this\ value\ should\ be\ somewhere\\ between\ 0.25\ and\ 4. }$

# %% [markdown]
# <font color = purple> $\mathtt{Factors\ which\ largely\ affect\ the\\ chi\ squared\ value\ are\ your\ Systematic\\ and\ Random\ errors.\ In\ the\\ cell\ below,\ suggest\ a\\ method\ to\ overcome\ each\ one\\ of\ the\ errors\ you\ identified. }$

# %%
boyles_syst_sugg = 'Suggestions\ here.\ '

# %store boyles_syst_sugg

boyles_rand_sugg = 'Suggestions\ here.\ '

# %store boyles_rand_sugg

# %% [markdown]
# <font color = purple> $\mathtt{Now\ to\ plot\ the\ calculated\ data\ ... }$

# %%
fig = plt.figure(figsize = (11, 8))
plt.xlabel('pressure /kPa')
plt.ylabel('1/V')
plt.errorbar(xData, yData, yError, xError, marker='o', linestyle='', label='data')
plt.plot(xPlot, fitData, color = 'r', label = 'fit')
plt.legend(loc = 2)
plt.grid(linestyle = '--', color = 'purple', alpha = 0.35)

# %% [markdown]
# <font color= purple> $\mathtt{Does\ this\ plot\ look\ like\ you\ expected?\\ Describe\ the\ plot\ you\ have\ produced\\ and\ explain\ any\ physical\ interpretations\\ you\ can\ conclude\ from\ it.\ }$

# %%
boyles_plot_desc = 'Describe\ your\ plot\ here.\ '

# %store boyles_plot_desc

boyles_phys_int = 'Explain\ any\ physical\ interpretations\ here.\ '

# %store boyles_phys_int

# %% [markdown]
# <font color = purple> $\mathtt{Look\ back\ at\ your\ initial\ expectations,\\ were\ you\ correct\ in\ your\ hypothesis?\ }$

# %%
boyles_hyp_comp = 'Correct\ Incorrect\ '

# %store boyles_hyp_comp

# %% [markdown]
# <font color = purple> $\mathtt{The\ answers\ you\ have\ given\ to\ the\ lab\\ script\ questions\ will\ now\ be\ inputted\\ into\ the\ following\ text.\ To\ view,\\ please\ exit\ the\ presentation\ and\\ run\ the\ following\ cell:\ }$

# %%
# %%mmd
# <font color = purple>
# $\mathtt{To\ investigate\ Boyles\ Law,\ My\ independent\ variables\ will\ be: {{boyles_in_vars}} \\ }$
#
# $\mathtt{ This\ is\ because\\ {{boyles_in_vars_reasons}} \\ }$
#
# $\mathtt{My\ dependent\ variables\ will\ be: \\ {{boyles_dep_vars}}  as\\ {{boyles_dep_vars_reasons}} \\ }$
#
# $\mathtt{I\ will\ need\ to\ control: \\ {{boyles_con_vars}} \\ So\ that\ {{boyles_con_vars_reasons}} \\ }$
#
# $\mathtt{When\ performing\ the\ experiment\ I\ encountered\ the\ following\ issues: \\ {{boyles_equip_issues}} \\ }$
#
# $\mathtt{To\ overcome\ these\ issues\ I\ decided\ to: {{boyles_equip_decisions}} \\ }$
#
# $\mathtt{In\ addition\ I\ came\ accross\ the\ following\ issues\ in\ the\ method.\\ {{boyles_method_issues}} \\ To\ overcome\ these\ I\ decided\ to\\ {{boyles_method_decisions}} \\ }$
#
# $\mathtt{It\ is\ possible\ I\ will\ encounter\ the\ following\\ systematic\ errors. \\ {{boyles_syst_err}} \\ }$
#
# $\mathtt{To\ overcome\ these\ possible\ systematic\ errors,\ I\ could:\ \\ {{boyles_syst_sugg}} \\ }$
#
# $\mathtt{I\ could\ also\ encounter\ the\ following\ random\ errors\ {{boyles_rand_err}} \\ } $
#
# $\mathtt{To\ reduce\ the\ impact\ of\ these\ random\ errors,\ I\ could\ {{boyles_rand_sugg}} \\ }$
#
# $\mathtt{From\ my\ understanding\ of\ the\ science\ behind\ Boyles' \ law,\ I\ expected\ the\ following\ result\ when\ plotting\ the\ final\ graph\ {{boyles_init_desc}} .\\ }$
#
# $\mathtt{The\ plot\ I\ actually\ produced\ from\ my\ Boyles'\ Law\ investigation\ shows\ {{boyles_plot_desc}} .\\ Meaning {{boyles_phys_int}} .\\ Therefore,\ my\ original\ interpretation\ was\ {{boyles_hyp_comp}} \\ }$

# %% [markdown]
# ## <font color = purple> $\mathtt{Charles'\ Law}$
# > ### <font color = purple> $\mathtt{T_1V_2 = T_2V_1}$
# > <font color = purple> $\mathtt{When\ kept\ at\ a\ constant\ pressure,\\ the\ absolute\ temperature\ and\\ volume\ of\ a\ gas\ are\ directly\\ proportional.\ }$

# %% [markdown]
# <font color = purple> $\mathtt{Your\ task\ is\ to\ produce\ a\ plot\\ of\ Volume\ against\ temperature.\\ What\ do\ you\ expect\ your\ plot\\ to\ look\ like?\ }$

# %%
charles_init_desc = 'Describe\ and\ explain\ the\ results\ you\ expect\ here.\ '

# %store charles_init_desc

# %% [markdown]
# <font color = purple> $\mathtt{Charles'\ Law\ Equipment\ List:\ }$
#
# > ![Screenshot%202021-05-02%20at%2019.01.51.png](attachment:Screenshot%202021-05-02%20at%2019.01.51.png)

# %% [markdown]
# <font color = purple> $\mathtt{Method: }$
#
# ![CMethod.png](attachment:CMethod.png)

# %% [markdown]
# <font color = purple> $\mathtt{After\ reading\ the\ methodology,\\ identify\ and\ explain\ your\\ independent\ variables:\ }$

# %%
charles_in_vars = 'List\ your\ independent\ variables\ here.\ '

# %store charles_in_vars

charles_in_vars_reasons = 'Explain\ your\ list\ of\ independent\ variables\ here.\ '

# %store charles_in_vars_reasons

# %% [markdown]
# <font color = purple> $\mathtt{Now,\ identify\ and\ explain\ your\\ dependent\ variables:\ }$

# %%
charles_dep_vars = 'List\ your\ dependent\ variables\ here.\ '

# %store charles_dep_vars


charles_dep_vars_reasons = 'Explain\ your\ dependent\ variables\ here.\ '

# %store charles_dep_vars_reasons

# %% [markdown]
# <font color = purple> $\mathtt{Identify\ and\ explain\ your\\ control\ variables:\ }$

# %%
charles_con_vars = 'List\ your\ control\ variables\ here.\ '

# %store charles_con_vars


charles_con_vars_reasons = 'Explain\ your\ control\ variables\ here.\ '

# %store charles_con_vars_reasons

# %% [markdown]
# <font color = purple> $\mathtt{For\ your\ room\ temperature\ volume,\\ you\ can\ use\ your\ atmospheric\ (atm)\\ volume\ calculated\ in\ the\ Boyle's\ Law\\ Investigation.\ }$ </font>

# %% [markdown]
# <font color = purple> $\mathtt{What\ issues\ could\ you\ encounter\ by\\ using\ the\ atm\ volume\ calculated\ in\\ the\ Boyle's\ Law\ Investigation? }$

# %%
issues_atm_volB = 'Type\ your\ identified\ issues\ here.'

# %store issues_atm_volB
# Out:
# Stored 'issues_atm_volB' (str)

# %% [markdown]
# <font color = purple> $\mathtt{Suggest\ how\ you\ could\ overcome\\ these\ issues\ }$

# %%
solve_issues_atm_volB = 'Type\ your\ Solutions\ here.'

# %store solve_issues_atm_volB
# Out:
# Stored 'solve_issues_atm_volB' (str)

# %% [markdown]
# <font color = purple> $\mathtt{Identify\ any\ systematic\ errors\ you\\ could\ encounter\ and\ suggest\ how\ you\\ could\ overcome\ them\ }$

# %%
charles_sys_err = 'Type\ your\ systematic\ errors\ here.'

# %store charles_sys_err

charles_sys_sols = 'Type\ your\ Solutions\ here.'

# %store charles_sys_sols

# %% [markdown]
# <font color = purple> $\mathtt{Identify\ any\ random\ errors\ you\\ could\ encounter\ and\ suggest\ how\ you\\ could\ overcome\ them\ }$

# %%
charles_rand_err = 'Type\ your\ random\ errors\ here.'

# %store charles_rand_err

charles_rand_sols = 'Type\ your\ Solutions\ here.'

# %store charles_rand_sols

# %%
room_temp = 20
room_temp_vol = inflated_Vol_atmp

cold_temp = 4
cold_temp_vol = inflated_Vol_atmp*0.2

hot_temp = 40
hot_temp_vol = inflated_Vol_atmp*2

temp_error = 1


ydata_charles = [cold_temp_vol, inflated_Vol_atmp, hot_temp_vol]
yerror_charles = np.array(np.sqrt(ydata_charles))
xdata_charles = [cold_temp, room_temp, hot_temp]
xerror_charles = np.array(temp_error)

XData = np.array(xdata_charles)
YData = np.array(ydata_charles)

# %% [markdown]
# <font color = purple> $\mathtt{Did\ you\ encounter\ any\ issues\\ with\ the\ equipment\ when\ performing\\ this\ experiment?\ Describe\ your\\ issues\ below\ and\ explain\ how\ you\\ overcame\ them\ }$

# %%
charles_equip_issues = 'Describe\ your\ issues\ here.\ '

# %store charles_equip_issues

charles_equip_sols = 'Explain\ your\ solutions\ here.\ '

# %store charles_equip_sols

# %% [markdown]
# <font color = purple> $\mathtt{In\ the\ cell\ below\ change\ the\ code\ to\ input\ your\ guesses\\ for\ the\ gradient\ and\ the\ intercept.\ These\ guesses\ do\\ not\ have\ to\ be\ accurate\ the\ algorithm\ just\ needs\ a\ best\\ guess\ in\ order\ to\ fit\ correctly }$ </font>

# %%
m1 = 60
c1 = 28

pInit = np.array([m1,c1])

# %% [markdown]
# <font color = purple> $\mathtt{Explain\ your\ gradient\ and\ intercept\ guesses: }$

# %%
charles_m_c_guess = 'Type\ your\ reasonings\ here.'

# %store charles_m_c_guess
# Out:
# Stored 'charles_m_c_guess' (str)

# %%
# Run fit
output = least_squares(calcChiSq, pInit, args = (XData, YData, xerror_charles, yerror_charles))

# Get least_squares output, stored in array output.x[]
A = output.x[0]
b = output.x[1]

# Get errors from our fits using fitStdError(), defined above
pErrors = fitStdError(output.jac)
d_A = pErrors[0]
d_b = pErrors[1]

# Calculate chis**2 per point, summed chi**2 and chi**2/NDF
chiarr = calcChiSq(output.x, XData, YData, xerror_charles, yerror_charles)**2
chisq = np.sum(chiarr)
NDF = nPoints - nPars
chisqndf = chisq/NDF

# Calculate fitted y-values using our fit parameters and the original fit function
xPlot = np.linspace(np.min(XData), np.max(XData), 300)
fitData = fitFunc(output.x, xPlot)

# %% [markdown]
# <font color = purple> $\mathtt{Parameter\ output: }$ </font>

# %%
print("Fitted parameters m: {0:.10f}, c: {1:.2f}".format(b, A))
print("Parameter errors: m: {0:.10f}, c: {1:.2f}".format(d_b, d_A))
print("ChiSq = {:5.5e}, ChiSq/NDF = {:5.10f}.".format(chisq, chisqndf))
# Out:
# Fitted parameters m: 67.5000000000, c: -0.00
# Parameter errors: m: 3.0491110088, c: 72.59
# ChiSq = 6.69500e-31, ChiSq/NDF = 0.0000000000.

# %% [markdown]
# <font color = purple> $\mathtt{Now\ plot\ the\ data\ ... }$ </font>

# %%
fig = plt.figure(figsize = (11, 8))
plt.xlabel('\nTemperature')
plt.ylabel('Volume \n')
plt.errorbar(XData, YData, yerror_charles, xerror_charles, marker='o', linestyle='', label='data')
plt.plot(xPlot, fitData, color = 'r')
plt.legend(loc = 2)
plt.grid(linestyle = '--', color = 'purple', alpha = 0.35)
plt.show()

# %% [markdown]
# <font color= purple> $\mathtt{Does\ this\ plot\ look\ like\ you\ expected?\\ Describe\ the\ plot\ you\ have\ produced\\ and\ explain\ any\ physical\ interpretations\\ you\ can\ conclude\ from\ it.\ }$

# %%
charles_plot_desc = 'Describe\ your\ plot\ here.\ '

# %store charles_plot_desc

charles_phys_int = 'Explain\ any\ physical\ interpretations\ here.\ '

# %store charles_phys_int

# %% [markdown]
# <font color = purple> $\mathtt{Look\ back\ at\ your\ initial\ expectations,\\ were\ you\ correct\ in\ your\ hypothesis?\ }$

# %%
charles_hyp_comp = 'Correct\ Incorrect\ '

# %store charles_hyp_comp

# %% [markdown]
# <font color = purple>
# $\mathtt{This\ worksheet\ explores\ the\ beginnings\ of\\ the\ Ideal\ Gas\ Law.\\ This\ is\ made\ up\ of\ Boyles',\\ Charles'\ and,\ Gay-Lussac's\ Laws. \\ State\ the\ Gay-Lussac\ law\ and\ describe\\ what\ you\ would\ expect\ to\ see\ from\ an\\ experimental\ investigation\ plotting\\ pressure\ against\ temperature.\ }$

# %%
gay_lussac_law = 'State\ the\ Gay-Lussac\ Law\ here.\ You\ are\ not\ expected\ to\ know\ this\ so\ google\ it!\ '

# %store gay_lussac_law

GL_exp = 'Describe\ any\ experimental\ results\ here.\ '

# %store GL_exp

# %% [markdown]
# <font color = purple> $\mathtt{From\ your\ knowledge\ of\ the\ Gay-Lussac\ Law,\\ Suggest\ a\ way\ in\ which\ we\ could\\ investigate\ it\ using\ a\ similar\ method\ to\\ the\ one\ we\ have\ used\ today\ }$

# %%
GL_exp_sugg = 'Explain\ your\ suggested\ method\ here.\ '

# %store GL_exp_sugg

# %% [markdown]
# <font color = purple> $\mathtt{The\ answers\ you\ have\ given\ to\ the\ lab\\ script\ questions\ will\ now\ be\ inputted\\ into\ the\ following\ text.\ To\ view,\\ please\ exit\ the\ presentation\ and\\ run\ the\ following\ cell:\ }$

# %%
# %%mmd
# <font color = purple>
#
# $\mathtt{To\ investigate\ Charles'\ Law,\ My\ independent\ variables\ will\ be:\\ {{charles_in_vars}} .\\ }$
#
# $\mathtt{ This\ is\ because\\ {{charles_in_vars_reasons}} .\\ }$
#
# $\mathtt{My\ dependent\ variables\ will\ be:\\ {{charles_dep_vars}} .\\  as\\ {{charles_dep_vars_reasons}} .\\ }$
#
# $\mathtt{I\ will\ need\ to\ control:\\ {{charles_con_vars}}  .\\ because:\\ {{charles_con_vars_reasons}}  .\\ }$
#
# $\mathtt{By\ using\ the\ same\ data\ point\ I\ calculated\ in the\ previous\ investigation,\ I\ could\ encounter\ the\ following\ issues:\\ {{issues_atm_volB}} .\\ }$
#
# $\mathtt{I\ could\ overcome\ these\ issues\ by:\\ {{solve_issues_atm_volB}} .\\ }$
#
# $\mathtt{I\ came\ accross\ the\ following\ issues\ with\ my\ equipment:\\ {{charles_equip_issues}} .\\}$
#
# $\mathtt{I\ solved\ these\ issues\ by:\\ {{charles_equip_sols}} .\\ }$
#
# $\mathtt{It\ is\ possible\ I\ will\ encounter\ the\ following\\ systematic\ errors:\\ {{charles_sys_err}} .\\ }$
#
# $\mathtt{To\ overcome\ these\ possible\ systematic\ errors,\ I\ will\ need\ to:\\ {{charles_sys_sols}} .\\ }$
#
# $\mathtt{I\ could\ also\ encounter\ the\ following\ random\ errors:\\ {{charles_rand_err}} .\\ } $
#
# $\mathtt{To\ reduce\ the\ impact\ of\ these\ random\ errors,\ I\ could:\\ {{charles_rand_sols}} .\\ }$
#
# $\mathtt{From\ my\ understanding\ of\ the\ science\ behind\ Charles' \ law,\ I\ expected\ the\ following\ result\ when\ plotting\ the\ final\ graph\ {{charles_init_desc}} .\\ }$
#
# $\mathtt{I\ chose\ my\ intercept\ and\ gradient\ guesses\ because:\\ {{charles_m_c_guess}} .\\ }$
#
# $\mathtt{The\ plot\ I\ actually\ produced\ from\ my\ Charles'\ Law\ investigation\ has:\\ {{charles_plot_desc}} .\\ Meaning:\\ {{charles_phys_int}} .\\ Therefore,\ my\ original\ interpretation\ was:\\ {{charles_hyp_comp}} .\\ }$
#
# $\mathtt{The\ Gay-Lussac\ Law\ is: \\ {{gay_lussac_law}} .\\ }$
#
# $\mathtt{From\ an\ experiment\ i\ would\ expect\ to\ see:\\ {{GL_exp}} .\\ }$
#
# $\mathtt{To\ investigate\ this\ law\ using\ a\ similar\ form\ of\ experimentation,\ I\ suggest\ the\ following\ method:\ {{GL_exp_sugg}} .\\ }$
